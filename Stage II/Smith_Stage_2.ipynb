# %%
import numpy as np
import pandas as pd

# %%
ny_confirmed = pd.read_csv("data/covid_confirmed_usafacts.csv")
ny_confirmed = ny_confirmed[ny_confirmed['StateFIPS'] == 36]
ny_confirmed = ny_confirmed.drop(ny_confirmed.iloc[:, 4 : 865], axis=1)
ny_confirmed = ny_confirmed.drop(ny_confirmed.iloc[:, 218 : 234], axis=1)

#ny_confirmed['06/01 - mean'] = ny_confirmed.iloc[:, 4:11].mean(axis=1)
#ny_confirmed['06/01 - median'] = ny_confirmed.iloc[:, 4:11].median(axis=1)
#ny_confirmed['06/01 - mode'] = ny_confirmed.iloc[:, 4:11].mode(axis=1)

#ny_confirmed['06/01'] = ny_confirmed.describe(ny_confirmed.iloc[:, 4:11])

ny_confirmed
# Out:
#       countyFIPS            County Name State  StateFIPS  2022-06-01  \
# 1860           0  Statewide Unallocated    NY         36           0
# 1861       36001         Albany County     NY         36       66065
# 1862       36003       Allegany County     NY         36        9499
# 1863       36005          Bronx County     NY         36      413505
# 1864       36007         Broome County     NY         36       50431
# ...          ...                    ...   ...        ...         ...
# 1918       36115     Washington County     NY         36       13370
# 1919       36117          Wayne County     NY         36       18891
# 1920       36119    Westchester County     NY         36      274175
# 1921       36121        Wyoming County     NY         36        8928
# 1922       36123          Yates County     NY         36        3793
#
#       2022-06-02  2022-06-03  2022-06-04  2022-06-05  2022-06-06  ...  \
# ...

# %%
ny_deaths = pd.read_csv("data/covid_deaths_usafacts.csv", index_col=None)
ny_deaths = ny_deaths[ny_deaths['StateFIPS'] == 36]
ny_deaths = ny_deaths.drop(ny_deaths.iloc[:, 4 : 865], axis=1)
ny_deaths = ny_deaths.drop(ny_deaths.iloc[:, 218 : 234], axis=1)

ny_deaths
# Out:
#       countyFIPS            County Name State  StateFIPS  2022-06-01  \
# 1860           0  Statewide Unallocated    NY         36         467
# 1861       36001         Albany County     NY         36         536
# 1862       36003       Allegany County     NY         36         156
# 1863       36005          Bronx County     NY         36        7755
# 1864       36007         Broome County     NY         36         530
# ...          ...                    ...   ...        ...         ...
# 1918       36115     Washington County     NY         36         116
# 1919       36117          Wayne County     NY         36         179
# 1920       36119    Westchester County     NY         36        2730
# 1921       36121        Wyoming County     NY         36          85
# 1922       36123          Yates County     NY         36          40
#
#       2022-06-02  2022-06-03  2022-06-04  2022-06-05  2022-06-06  ...  \
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c8b9407f-9b55-4516-885c-d1bc9453ac0b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
